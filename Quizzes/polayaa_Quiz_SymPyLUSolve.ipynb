# %% [markdown]
# # 1. Solve the using *LUsolve* from sympy the   2 $\times$ 2 system $Ax=b$, inside the function *LUsolve_2_by_2_lin_sys* with
#
# $$A = \left[
#   \begin{array}{cc}
# e & i\\
#  \sqrt{2}& \pi
# \end{array}
# \right]
# $$
#
# $$b  = \left[
#   \begin{array}{c}
# \sqrt{3} \\
# 1
# \end{array}
# \right]
# $$

# %%
! pip uninstall sympy
# Out:
# Found existing installation: sympy 1.14.0
# Uninstalling sympy-1.14.0:
#   Would remove:
#     /usr/local/bin/isympy
#     /usr/local/lib/python3.12/dist-packages/isympy.py
#     /usr/local/lib/python3.12/dist-packages/sympy-1.14.0.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/sympy/*
#     /usr/local/share/man/man1/isympy.1
# Proceed (Y/n)? y
#   Successfully uninstalled sympy-1.14.0

# %%
! pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy) (1.3.0)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 36.9 MB/s eta 0:00:00
# Installing collected packages: sympy
# Successfully installed sympy-1.14.0

# %%
from sympy import *
init_printing()

def LUsolve_2_by_2_lin_sys():

    A = Matrix([[E,I],
                [sqrt(2),pi]])
    b = Matrix(2,1,[sqrt(3),1])

    x = A.LUsolve(b)

    return x

# %% [markdown]
# # 2. Solve the using *solve* from sympy the   2 $\times$ 2 system $Ax=b$, inside the function *solve_2_by_2_lin_sys* with
#
# $$A = \left[
#   \begin{array}{cc}
# e & i\\
#  \sqrt{2}& \pi
# \end{array}
# \right]
# $$
#
# $$b  = \left[
#   \begin{array}{c}
# \sqrt{3} \\
# 1
# \end{array}
# \right]
# $$

# %%
from sympy import *
init_printing()

def solve_2_by_2_lin_sys():

  A = Matrix([[E,I],
              [sqrt(2),pi]])
  b = Matrix(2,1,[sqrt(3),1])

  x = Matrix(2,1,symbols('x1:3'))

  sol = linsolve(list(A@x-b),list(x))

  return sol
